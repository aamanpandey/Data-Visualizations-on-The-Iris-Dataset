# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-Iris-Dataset" data-toc-modified-id="Load-Iris-Dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load Iris Dataset</a></span></li><li><span><a href="#Checking-if-Data-Need-Cleaning" data-toc-modified-id="Checking-if-Data-Need-Cleaning-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Checking if Data Need Cleaning</a></span></li><li><span><a href="#Data-Visualizations" data-toc-modified-id="Data-Visualizations-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Visualizations</a></span><ul class="toc-item"><li><span><a href="#Scator-Plot" data-toc-modified-id="Scator-Plot-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Scator Plot</a></span></li><li><span><a href="#Boxplot" data-toc-modified-id="Boxplot-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Boxplot</a></span></li><li><span><a href="#Violin-Plot" data-toc-modified-id="Violin-Plot-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Violin Plot</a></span></li><li><span><a href="#FacetGrid" data-toc-modified-id="FacetGrid-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>FacetGrid</a></span></li><li><span><a href="#Pair-Plot" data-toc-modified-id="Pair-Plot-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Pair Plot</a></span></li><li><span><a href="#Andrews-Curves" data-toc-modified-id="Andrews-Curves-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Andrews Curves</a></span></li><li><span><a href="#Parallel-Coordinates-Plots" data-toc-modified-id="Parallel-Coordinates-Plots-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Parallel Coordinates Plots</a></span></li><li><span><a href="#Radviz" data-toc-modified-id="Radviz-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Radviz</a></span></li></ul></li></ul></div>

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# Data Visualizations on The Iris Dataset

# %% [markdown]
# Iris Dataset:
# The Iris flower data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species. The data set consists of 50 samples from each of three species of Iris (Iris Setosa, Iris virginica, and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
#
# Link:https://archive.ics.uci.edu/ml/datasets/Iris
#
# Columns Descriptions:
#
# Id: SPL-SPW-PTL-PTW(CM);
#
# SepalLengthCm: Length of the sepal (in cm);
#
# SepalWidthCm: Width of the sepal (in cm);
#
# PetalLengthCm: Length of the petal (in cm);
#
# PetalWidthCm: Width of the petal (in cm);
#
# Species : Species name;

# %%
from IPython.display import Image
Image(filename='iris.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Iris Dataset

# %%
data = pd.read_csv("Iris.csv")

# %% [markdown]
# # Checking if Data Need Cleaning

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Summary of varibles of Iris Dataset

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Checking for null values
data.isnull().mean()
# Out:
# Id               0.0
# SepalLengthCm    0.0
# SepalWidthCm     0.0
# PetalLengthCm    0.0
# PetalWidthCm     0.0
# Species          0.0
# dtype: float64

# %% [markdown]
# There is no null values in the Iris dataset

# %% [markdown]
# #Let's see how many examples we have of each species

# %%
data["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# ## Scator Plot

# %% [markdown]
# Scator plot of the Iris Feature

# %%
data.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")

# %% [markdown]
# Scator plot of the Iris Feature using seaburn libraray

# %%
sns.scatterplot(x="SepalLengthCm", y="SepalWidthCm", data=data)

# %%
Scator plot of the Iris Feature using seaburn libraray

# %%
sns.scatterplot(x="SepalLengthCm", y="SepalWidthCm", hue= "Species", data=data)

# %% [markdown]
# ## Boxplot

# %% [markdown]
# We can look at an individual feature in Seaborn through a boxplot
# Boxplot help us to identify the outliers in the dataset

# %%
sns.boxplot(x="Species", y="PetalLengthCm", data=data)

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# A violin plot combines the benefits of the previous two plots and simplifies them
# It shows the distribution of quantitative data across several levels of one (or more)
# categorical variables such that those distributions can be compared. Denser regions of
# the data are fatter, and sparser thiner in a violin plot

# %%
sns.violinplot(x="Species", y="PetalLengthCm", data=data, size=6)

# %% [markdown]
# ## FacetGrid

# %% [markdown]
# The FacetGrid class is useful when you want to visualize the distribution of a variable
# or the relationship between multiple variables separately within subsets of your dataset.

# %%
sns.FacetGrid(data, hue="Species", height=6).map(sns.kdeplot, "PetalLengthCm").add_legend()

# %%
p=sns.FacetGrid(data, col="Species")
p.map(sns.distplot, "PetalLengthCm")

# %%
p=sns.FacetGrid(data, col="Species", height=4, aspect=1)
p.map(plt.hist, "PetalLengthCm")

# %% [markdown]
# ## Pair Plot

# %% [markdown]
# Another useful seaborn plot is the pairplot, which shows the bivariate relation
# By default, this function will create a grid of Axes such that each numeric variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.
# The diagonal Axes are treated differently, drawing a plot to show the univariate distribution of the data for the variable in that column

# %%
sns.pairplot(data.drop("Id", axis=1), hue="Species", height=3)

# %% [markdown]
# ## Andrews Curves

# %% [markdown]
# Andrews curves plot is a way of visualizing the structure of independent variables. The possible usage is a lightweight method of checking whether we have enough features to train a classifier or whether we should keep doing feature engineering and cleaning data because there is a mess in data.

# %%
from pandas.plotting import andrews_curves
andrews_curves(data.drop("Id", axis=1), "Species")

# %% [markdown]
# ## Parallel Coordinates Plots

# %% [markdown]
# Parallel Coordinates Plots are ideal for comparing many variables together and
# seeing the relationships between them
#
# Link: https://www.data-to-viz.com/graph/parallel.html

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates(data.drop("Id", axis=1), "Species")

# %% [markdown]
# ## Radviz

# %% [markdown]
# RadViz allow to project a N-dimensional data set into a 2D space where the influence of
# each dimension can be interpreted as a balance between the influence of all dimensions.
#
# Link: https://pandas.pydata.org/docs/reference/api/pandas.plotting.radviz.html

# %%
from pandas.plotting import radviz
radviz(data.drop("Id", axis=1), "Species")
